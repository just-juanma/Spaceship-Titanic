# %%
# %%capture
# %run 3.0-ModelBuildingForScaledData.ipynb

# %% [markdown]
# 1. Importing libraries

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# %%
def model_prediction(model):
    model.fit(x_train, y_train.values.reshape(-1, ))
    x_train_pred = model.predict(x_train)
    x_test_pred = model.predict(x_test)
    accuracy_train = accuracy_score(y_train, x_train_pred) * 100
    accuracy_test = accuracy_score(y_test, x_test_pred) * 100
    training_score.append(accuracy_train)
    testing_score.append(accuracy_test)
    precision_scr = precision_score(y_test, x_test_pred)
    recall_scr = recall_score(y_test, x_test_pred)
    f1_scr = f1_score(y_test, x_test_pred)
    print(f"Accuracy Score of {model} model on Training Data is: {accuracy_train}")
    print(f"Accuracy Score of {model} model on Testing Data is: {accuracy_test}")
    print(f"Precision Score of {model} model is: {precision_scr}")
    print(f"Recall Score of {model} model is: {recall_scr}")
    print(f"F1 Score of {model} model is: {f1_scr}")
    print(f"Confusion Matrix of {model} model is:")
    cm = confusion_matrix(y_test, x_test_pred)
    plt.figure(figsize = (10, 5))
    sns.heatmap(cm, annot = True, fmt = "g", cmap = "summer")

# %% [markdown]
# 2. Decision Tree Classifier Model

# %%
model_prediction(DecisionTreeClassifier())
# Out:
# Accuracy Score of DecisionTreeClassifier() model on Training Data is: 98.47569744032212
# Accuracy Score of DecisionTreeClassifier() model on Testing Data is: 75.0431282346176
# Precision Score of DecisionTreeClassifier() model is: 0.7534403669724771
# Recall Score of DecisionTreeClassifier() model is: 0.75
# F1 Score of DecisionTreeClassifier() model is: 0.751716247139588
# Confusion Matrix of DecisionTreeClassifier() model is:

# %% [markdown]
# 3. Radom Forest Classifier Model

# %%
model_prediction(RandomForestClassifier())
# Out:
# Accuracy Score of RandomForestClassifier() model on Training Data is: 98.46131722749497
# Accuracy Score of RandomForestClassifier() model on Testing Data is: 80.39102932719953
# Precision Score of RandomForestClassifier() model is: 0.830655129789864
# Recall Score of RandomForestClassifier() model is: 0.7671232876712328
# F1 Score of RandomForestClassifier() model is: 0.797626112759644
# Confusion Matrix of RandomForestClassifier() model is:

# %% [markdown]
# 4. Ada Boost Classifier Model

# %%
model_prediction(AdaBoostClassifier())
# Out:
# Accuracy Score of AdaBoostClassifier() model on Training Data is: 79.98274374460742
# Accuracy Score of AdaBoostClassifier() model on Testing Data is: 79.24094307073031
# Precision Score of AdaBoostClassifier() model is: 0.7657378740970072
# Recall Score of AdaBoostClassifier() model is: 0.8470319634703196
# F1 Score of AdaBoostClassifier() model is: 0.8043360433604336
# Confusion Matrix of AdaBoostClassifier() model is:

# %% [markdown]
# 5. Gradient Boosting Classifier

# %%
model_prediction(GradientBoostingClassifier())
# Out:
# Accuracy Score of GradientBoostingClassifier() model on Training Data is: 82.053494391717
# Accuracy Score of GradientBoostingClassifier() model on Testing Data is: 79.29844738355378
# Precision Score of GradientBoostingClassifier() model is: 0.7721518987341772
# Recall Score of GradientBoostingClassifier() model is: 0.8356164383561644
# F1 Score of GradientBoostingClassifier() model is: 0.8026315789473685
# Confusion Matrix of GradientBoostingClassifier() model is:

# %% [markdown]
# 6. LGMB Classifier Model

# %%
# TODO: [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
model_prediction(LGBMClassifier(force_row_wise = True))
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 3502, number of negative: 3452
# [LightGBM] [Info] Total Bins 1665
# [LightGBM] [Info] Number of data points in the train set: 6954, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.503595 -> initscore=0.014380
# [LightGBM] [Info] Start training from score 0.014380
# Accuracy Score of LGBMClassifier(force_row_wise=True) model on Training Data is: 88.22260569456428
# Accuracy Score of LGBMClassifier(force_row_wise=True) model on Testing Data is: 80.21851638872916
# Precision Score of LGBMClassifier(force_row_wise=True) model is: 0.789760348583878
# Recall Score of LGBMClassifier(force_row_wise=True) model is: 0.8276255707762558
# F1 Score of LGBMClassifier(force_row_wise=True) model is: 0.8082497212931995
# Confusion Matrix of LGBMClassifier(force_row_wise=True) model is:

# %% [markdown]
# 7. XGBClassifier Model

# %%
model_prediction(XGBClassifier())
# Out:
# Accuracy Score of XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...) model on Training Data is: 92.52228932988208
# Accuracy Score of XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
# ...

# %% [markdown]
# 8. CatBoostClassifier Model

# %%
model_prediction(CatBoostClassifier(verbose = False))
# Out:
# Accuracy Score of <catboost.core.CatBoostClassifier object at 0x7fdf66ce86a0> model on Training Data is: 87.40293356341674
# Accuracy Score of <catboost.core.CatBoostClassifier object at 0x7fdf66ce86a0> model on Testing Data is: 81.48361127084532
# Precision Score of <catboost.core.CatBoostClassifier object at 0x7fdf66ce86a0> model is: 0.8050660792951542
# Recall Score of <catboost.core.CatBoostClassifier object at 0x7fdf66ce86a0> model is: 0.8344748858447488
# F1 Score of <catboost.core.CatBoostClassifier object at 0x7fdf66ce86a0> model is: 0.8195067264573991
# Confusion Matrix of <catboost.core.CatBoostClassifier object at 0x7fdf66ce86a0> model is:
